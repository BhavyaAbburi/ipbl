# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("payment_fraud.csv")
data2=pd.read_csv("insurance_cross_sell.csv")

# %%
data1.head()
data1.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    39221.000000  39221.000000  39221.000000          39221.000000
# mean       857.563984      1.084751      4.748232            122.641326
# std        804.788212      0.566899      0.389360            283.569177
# min          1.000000      1.000000      0.421214              0.000000
# 25%         72.000000      1.000000      4.742303              0.000000
# 50%        603.000000      1.000000      4.886641              0.012500
# 75%       1804.000000      1.000000      4.962055             87.510417
# max       2000.000000     29.000000      5.040929           1999.580556
#
#               label
# count  39221.000000
# mean       0.014278
# std        0.118636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data2.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1           28                   0
# 1   2    Male   76                1            3                   0
# 2   3    Male   47                1           28                   0
# 3   4    Male   21                1           11                   1
# 4   5  Female   29                1           41                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes           40454                    26      217
# 1    1-2 Year             No           33536                    26      183
# 2   > 2 Years            Yes           38294                    26       27
# 3    < 1 Year             No           28619                   152      203
# 4    < 1 Year             No           27496                   152       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
data1.isnull()
# Out:
#        accountAgeDays  numItems  localTime  paymentMethod  \
# 0               False     False      False          False
# 1               False     False      False          False
# 2               False     False      False          False
# 3               False     False      False          False
# 4               False     False      False          False
# ...               ...       ...        ...            ...
# 39216           False     False      False          False
# 39217           False     False      False          False
# 39218           False     False      False          False
# 39219           False     False      False          False
# 39220           False     False      False          False
#
#        paymentMethodAgeDays  label
# 0                     False  False
# 1                     False  False
# 2                     False  False
# 3                     False  False
# 4                     False  False
# ...                     ...    ...
# ...

# %%
data2.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
fraud=data1[data1['label']==1]
print(fraud.describe())
# Out:
#        accountAgeDays    numItems   localTime  paymentMethodAgeDays  label
# count           560.0  560.000000  560.000000            560.000000  560.0
# mean              1.0    1.264286    4.555726              0.012476    1.0
# std               0.0    0.706329    0.610253              0.081981    0.0
# min               1.0    1.000000    2.596228              0.000000    1.0
# 25%               1.0    1.000000    4.505662              0.000000    1.0
# 50%               1.0    1.000000    4.748314              0.000000    1.0
# 75%               1.0    1.000000    4.921318              0.001389    1.0
# max               1.0   10.000000    5.040929              0.991667    1.0

# %%
fraud=fraud.drop("localTime",axis=1)

# %%
fraud.to_csv("fraud_transactions.csv",index=False)

# %%
label=data1["paymentMethod"]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
n_fraud=data1[data1['label']==0]
print(n_fraud.describe())
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    38661.000000  38661.000000  38661.000000          38661.000000
# mean       869.971211      1.082150      4.751020            124.417591
# std        803.917989      0.564218      0.384536            285.228464
# min          2.000000      1.000000      0.421214              0.000000
# 25%         81.000000      1.000000      4.745402              0.000000
# 50%        625.000000      1.000000      4.886641              0.017361
# 75%       1826.000000      1.000000      4.962055             90.713194
# max       2000.000000     29.000000      5.040929           1999.580556
#
#          label
# count  38661.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
for i in fraud['paymentMethod'].unique():
    print(i)
    temp=fraud[fraud["paymentMethod"]==i]
    print(len(temp))
# Out:
# paypal
# 9174
# storecredit
# 1893
# creditcard
# 27594

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='label', data=data1)
plt.title('Distribution of Fraudulent Transactions')
plt.show()

# %%
#value="creditcard"
#filtered_data = fraud[fraud['paymentMethod']]
plt.figure(figsize=(10, 6))
sns.scatterplot(x='paymentMethod',y='paymentMethodAgeDays',data=fraud)
#plt.title(f'Scatterplot for label={value}')
plt.xlabel('paymentMethod')
plt.ylabel('paymentMethodAgeDays')
plt.show()

# %%
sortedbydays = data1.sort_values(by = 'accountAgeDays')

# %%
days = sortedbydays['accountAgeDays'].unique()

# %%
data1
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 0                  29         1   4.745402        paypal
# 1                 725         1   4.742303   storecredit
# 2                 845         1   4.921318    creditcard
# 3                 503         1   4.886641    creditcard
# 4                2000         1   5.040929    creditcard
# ...               ...       ...        ...           ...
# 39216             986         1   4.836982    creditcard
# 39217            1647         1   4.876771    creditcard
# 39218            1591         1   4.742303    creditcard
# 39219             237         1   4.921318    creditcard
# 39220             272         1   5.040929        paypal
#
#        paymentMethodAgeDays  label
# 0                 28.204861      0
# 1                  0.000000      0
# 2                  0.000000      0
# 3                  0.000000      0
# 4                  0.000000      0
# ...                     ...    ...
# ...
