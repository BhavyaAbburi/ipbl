# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\navee\\IPBL\\week 3\\week3'

# %%
data = pd.read_csv('payment_fraud.csv')

# %%
data.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    39221.000000  39221.000000  39221.000000          39221.000000
# mean       857.563984      1.084751      4.748232            122.641326
# std        804.788212      0.566899      0.389360            283.569177
# min          1.000000      1.000000      0.421214              0.000000
# 25%         72.000000      1.000000      4.742303              0.000000
# 50%        603.000000      1.000000      4.886641              0.012500
# 75%       1804.000000      1.000000      4.962055             87.510417
# max       2000.000000     29.000000      5.040929           1999.580556
#
#               label
# count  39221.000000
# mean       0.014278
# std        0.118636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39221 entries, 0 to 39220
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accountAgeDays        39221 non-null  int64
#  1   numItems              39221 non-null  int64
#  2   localTime             39221 non-null  float64
#  3   paymentMethod         39221 non-null  object
#  4   paymentMethodAgeDays  39221 non-null  float64
#  5   label                 39221 non-null  int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ MB

# %%
nonfraud = data[data['label'] == 0]

# %%
nonfraud
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 0                  29         1   4.745402        paypal
# 1                 725         1   4.742303   storecredit
# 2                 845         1   4.921318    creditcard
# 3                 503         1   4.886641    creditcard
# 4                2000         1   5.040929    creditcard
# ...               ...       ...        ...           ...
# 39216             986         1   4.836982    creditcard
# 39217            1647         1   4.876771    creditcard
# 39218            1591         1   4.742303    creditcard
# 39219             237         1   4.921318    creditcard
# 39220             272         1   5.040929        paypal
#
#        paymentMethodAgeDays  label
# 0                 28.204861      0
# 1                  0.000000      0
# 2                  0.000000      0
# 3                  0.000000      0
# 4                  0.000000      0
# ...                     ...    ...
# ...

# %%
fraud = data[data['label'] == 1]

# %%
fraud
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 109                 1         4   4.836982    creditcard
# 243                 1         1   4.836982        paypal
# 280                 1         1   4.921318    creditcard
# 362                 1         1   4.524580        paypal
# 420                 1         1   4.748314        paypal
# ...               ...       ...        ...           ...
# 38830               1         2   4.876771    creditcard
# 38880               1         1   4.876771    creditcard
# 39005               1         1   4.505662    creditcard
# 39111               1         3   4.748314    creditcard
# 39183               1         1   3.575983        paypal
#
#        paymentMethodAgeDays  label
# 109                0.000000      1
# 243                0.002778      1
# 280                0.000000      1
# 362                0.000000      1
# 420                0.000000      1
# ...                     ...    ...
# ...

# %%
fraud.sort_values(by= 'paymentMethodAgeDays')
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 109                 1         4   4.836982    creditcard
# 23242               1         2   4.057414    creditcard
# 22865               1         1   4.748314    creditcard
# 22392               1         1   5.017904    creditcard
# 22194               1         1   4.745402    creditcard
# ...               ...       ...        ...           ...
# 2008                1         1   4.742303        paypal
# 38796               1         1   4.886641    creditcard
# 25806               1         1   4.745402    creditcard
# 37769               1         1   4.886641    creditcard
# 4361                1         1   4.921349    creditcard
#
#        paymentMethodAgeDays  label
# 109                0.000000      1
# 23242              0.000000      1
# 22865              0.000000      1
# 22392              0.000000      1
# 22194              0.000000      1
# ...                     ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# accountAgeDays          0
# numItems                0
# localTime               0
# paymentMethod           0
# paymentMethodAgeDays    0
# label                   0
# dtype: int64

# %%
data[data['accountAgeDays'] == 725]
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 1                 725         1   4.742303   storecredit
# 5548              725         1   4.962055    creditcard
# 12324             725         1   4.461622        paypal
# 37022             725         1   4.962055    creditcard
#
#        paymentMethodAgeDays  label
# 1                  0.000000      0
# 5548             724.846528      0
# 12324              0.000000      0
# 37022              0.000000      0

# %%
methods = data['paymentMethod'].unique()

# %%
for i in methods:
    print(i)
    temp =fraud[fraud['paymentMethod'] == i]
    print(len(temp))
# Out:
# paypal
# 129
# storecredit
# 21
# creditcard
# 410

# %%
fraud[fraud['paymentMethod'] == 'creditcard']
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 109                 1         4   4.836982    creditcard
# 280                 1         1   4.921318    creditcard
# 422                 1         1   4.745402    creditcard
# 461                 1         1   4.921318    creditcard
# 504                 1         1   4.921349    creditcard
# ...               ...       ...        ...           ...
# 38813               1         1   4.742303    creditcard
# 38830               1         2   4.876771    creditcard
# 38880               1         1   4.876771    creditcard
# 39005               1         1   4.505662    creditcard
# 39111               1         3   4.748314    creditcard
#
#        paymentMethodAgeDays  label
# 109                0.000000      1
# 280                0.000000      1
# 422                0.003472      1
# 461                0.000000      1
# 504                0.007639      1
# ...                     ...    ...
# ...

# %%
fraud[fraud['paymentMethod'] == 'creditcard'] .describe()
# Out:
#        accountAgeDays    numItems   localTime  paymentMethodAgeDays  label
# count           410.0  410.000000  410.000000            410.000000  410.0
# mean              1.0    1.248780    4.563589              0.013242    1.0
# std               0.0    0.590521    0.604205              0.087254    0.0
# min               1.0    1.000000    2.596228              0.000000    1.0
# 25%               1.0    1.000000    4.505662              0.000000    1.0
# 50%               1.0    1.000000    4.836982              0.000000    1.0
# 75%               1.0    1.000000    4.921318              0.001389    1.0
# max               1.0    5.000000    5.040929              0.991667    1.0

# %%
fraud[fraud['paymentMethod'] == 'paypal'] .describe()
# Out:
#        accountAgeDays    numItems   localTime  paymentMethodAgeDays  label
# count           129.0  129.000000  129.000000            129.000000  129.0
# mean              1.0    1.286822    4.522891              0.011289    1.0
# std               0.0    0.961719    0.625315              0.070446    0.0
# min               1.0    1.000000    2.596228              0.000000    1.0
# 25%               1.0    1.000000    4.505662              0.000000    1.0
# 50%               1.0    1.000000    4.748314              0.000694    1.0
# 75%               1.0    1.000000    4.895263              0.001389    1.0
# max               1.0   10.000000    5.040929              0.618750    1.0

# %%
fraud[fraud['paymentMethod'] == 'storecredit'] .describe()
# Out:
#        accountAgeDays   numItems  localTime  paymentMethodAgeDays  label
# count            21.0  21.000000  21.000000             21.000000   21.0
# mean              1.0   1.428571   4.603902              0.004828    1.0
# std               0.0   0.925820   0.655830              0.017757    0.0
# min               1.0   1.000000   2.596228              0.000000    1.0
# 25%               1.0   1.000000   4.742303              0.000000    1.0
# 50%               1.0   1.000000   4.748314              0.000000    1.0
# 75%               1.0   2.000000   4.895263              0.001389    1.0
# max               1.0   5.000000   5.034622              0.081944    1.0

# %%
nonfraud[nonfraud['paymentMethod'] == 'creditcard'] .describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    27594.000000  27594.000000  27594.000000          27594.000000
# mean       872.846416      1.083931      4.751374            124.879887
# std        804.220623      0.564398      0.384850            286.662606
# min          2.000000      1.000000      0.421214              0.000000
# 25%         82.000000      1.000000      4.745402              0.000000
# 50%        632.000000      1.000000      4.886641              0.016667
# 75%       1841.000000      1.000000      4.962055             90.099826
# max       2000.000000     29.000000      5.040929           1999.580556
#
#          label
# count  27594.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
nonfraud[nonfraud['paymentMethod'] == 'paypal'] .describe()
# Out:
#        accountAgeDays     numItems    localTime  paymentMethodAgeDays   label
# count     9174.000000  9174.000000  9174.000000           9174.000000  9174.0
# mean       865.449095     1.076957     4.750379            123.833288     0.0
# std        802.511084     0.563011     0.385643            283.352879     0.0
# min          2.000000     1.000000     0.421214              0.000000     0.0
# 25%         79.000000     1.000000     4.745402              0.000000     0.0
# 50%        619.000000     1.000000     4.886641              0.015972     0.0
# 75%       1804.000000     1.000000     4.962055             90.166493     0.0
# max       2000.000000    10.000000     5.040929           1988.273611     0.0

# %%
testing = nonfraud.sort_values(by = 'numItems')

# %%
testing[testing['numItems']>=6]
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 2197             1150         6   4.962055    creditcard
# 37805             265         6   2.948940    creditcard
# 26983             204         6   4.895263    creditcard
# 18659            2000         6   4.886641    creditcard
# 4591              142         6   4.965339        paypal
# ...               ...       ...        ...           ...
# 33602             252        10   4.921349        paypal
# 22157               6        11   4.742303    creditcard
# 6976              326        12   4.921349    creditcard
# 16292            1518        15   2.948940    creditcard
# 16374             141        29   4.921349    creditcard
#
#        paymentMethodAgeDays  label
# 2197               0.004167      0
# 37805            264.173611      0
# 26983            194.492361      0
# 18659            139.805556      0
# 4591             130.267361      0
# ...                     ...    ...
# ...

# %%
testing1 = fraud.sort_values(by = 'numItems')

# %%
testing1
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 19373               1         1   4.505662    creditcard
# 25710               1         1   4.836982    creditcard
# 25588               1         1   4.895263    creditcard
# 25440               1         1   4.836982    creditcard
# 25433               1         1   5.034622    creditcard
# ...               ...       ...        ...           ...
# 21663               1         5   4.745402    creditcard
# 33439               1         5   4.745402   storecredit
# 36189               1         5   3.954522    creditcard
# 36309               1         5   4.886641    creditcard
# 24329               1        10   5.040929        paypal
#
#        paymentMethodAgeDays  label
# 19373              0.000000      1
# 25710              0.031250      1
# 25588              0.008333      1
# 25440              0.000000      1
# 25433              0.000000      1
# ...                     ...    ...
# ...

# %%
testing[testing['numItems']<=5]
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 0                  29         1   4.745402        paypal
# 25833            1519         1   5.040929        paypal
# 25834             297         1   4.742303        paypal
# 25835             463         1   4.836982    creditcard
# 25837            2000         1   4.524580        paypal
# ...               ...       ...        ...           ...
# 34072             223         5   4.895263    creditcard
# 7717                5         5   4.895263    creditcard
# 34069              84         5   4.524580    creditcard
# 17465             247         5   4.886641        paypal
# 18920            2000         5   3.575983    creditcard
#
#        paymentMethodAgeDays  label
# 0                 28.204861      0
# 25833           1121.258333      0
# 25834            183.013194      0
# 25835            462.129861      0
# 25837            220.434722      0
# ...                     ...    ...
# ...

# %%
nonfraud.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    38661.000000  38661.000000  38661.000000          38661.000000
# mean       869.971211      1.082150      4.751020            124.417591
# std        803.917989      0.564218      0.384536            285.228464
# min          2.000000      1.000000      0.421214              0.000000
# 25%         81.000000      1.000000      4.745402              0.000000
# 50%        625.000000      1.000000      4.886641              0.017361
# 75%       1826.000000      1.000000      4.962055             90.713194
# max       2000.000000     29.000000      5.040929           1999.580556
#
#          label
# count  38661.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
fraud.describe()
# Out:
#        accountAgeDays    numItems   localTime  paymentMethodAgeDays  label
# count           560.0  560.000000  560.000000            560.000000  560.0
# mean              1.0    1.264286    4.555726              0.012476    1.0
# std               0.0    0.706329    0.610253              0.081981    0.0
# min               1.0    1.000000    2.596228              0.000000    1.0
# 25%               1.0    1.000000    4.505662              0.000000    1.0
# 50%               1.0    1.000000    4.748314              0.000000    1.0
# 75%               1.0    1.000000    4.921318              0.001389    1.0
# max               1.0   10.000000    5.040929              0.991667    1.0

# %%
for i in methods:
    print(i)
    temp =data[data['paymentMethod'] == i]
    print(len(temp))
# Out:
# paypal
# 9303
# storecredit
# 1914
# creditcard
# 28004

# %%
per
# Out:
# {'paypal': 98.61335053208641,
#  'storecredit': 98.90282131661442,
#  'creditcard': 98.53592343950865}

# %%
data.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    39221.000000  39221.000000  39221.000000          39221.000000
# mean       857.563984      1.084751      4.748232            122.641326
# std        804.788212      0.566899      0.389360            283.569177
# min          1.000000      1.000000      0.421214              0.000000
# 25%         72.000000      1.000000      4.742303              0.000000
# 50%        603.000000      1.000000      4.886641              0.012500
# 75%       1804.000000      1.000000      4.962055             87.510417
# max       2000.000000     29.000000      5.040929           1999.580556
#
#               label
# count  39221.000000
# mean       0.014278
# std        0.118636
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
nonfraud.describe()
# Out:
#        accountAgeDays      numItems     localTime  paymentMethodAgeDays  \
# count    38661.000000  38661.000000  38661.000000          38661.000000
# mean       869.971211      1.082150      4.751020            124.417591
# std        803.917989      0.564218      0.384536            285.228464
# min          2.000000      1.000000      0.421214              0.000000
# 25%         81.000000      1.000000      4.745402              0.000000
# 50%        625.000000      1.000000      4.886641              0.017361
# 75%       1826.000000      1.000000      4.962055             90.713194
# max       2000.000000     29.000000      5.040929           1999.580556
#
#          label
# count  38661.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
fraud.describe()
# Out:
#        accountAgeDays    numItems   localTime  paymentMethodAgeDays  label
# count           560.0  560.000000  560.000000            560.000000  560.0
# mean              1.0    1.264286    4.555726              0.012476    1.0
# std               0.0    0.706329    0.610253              0.081981    0.0
# min               1.0    1.000000    2.596228              0.000000    1.0
# 25%               1.0    1.000000    4.505662              0.000000    1.0
# 50%               1.0    1.000000    4.748314              0.000000    1.0
# 75%               1.0    1.000000    4.921318              0.001389    1.0
# max               1.0   10.000000    5.040929              0.991667    1.0

# %%
fraud.sort_values(by = 'accountAgeDays')
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 109                 1         4   4.836982    creditcard
# 27232               1         1   4.886641   storecredit
# 27094               1         1   3.954522    creditcard
# 27049               1         1   4.836982        paypal
# 26940               1         1   4.962055    creditcard
# ...               ...       ...        ...           ...
# 12929               1         1   2.948940        paypal
# 13046               1         1   3.954522    creditcard
# 13054               1         1   4.745402        paypal
# 12463               1         1   4.057414    creditcard
# 39183               1         1   3.575983        paypal
#
#        paymentMethodAgeDays  label
# 109                0.000000      1
# 27232              0.000000      1
# 27094              0.000000      1
# 27049              0.011806      1
# 26940              0.002083      1
# ...                     ...    ...
# ...

# %%
fraud
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 109                 1         4   4.836982    creditcard
# 243                 1         1   4.836982        paypal
# 280                 1         1   4.921318    creditcard
# 362                 1         1   4.524580        paypal
# 420                 1         1   4.748314        paypal
# ...               ...       ...        ...           ...
# 38830               1         2   4.876771    creditcard
# 38880               1         1   4.876771    creditcard
# 39005               1         1   4.505662    creditcard
# 39111               1         3   4.748314    creditcard
# 39183               1         1   3.575983        paypal
#
#        paymentMethodAgeDays  label
# 109                0.000000      1
# 243                0.002778      1
# 280                0.000000      1
# 362                0.000000      1
# 420                0.000000      1
# ...                     ...    ...
# ...

# %%
nonfraud.sort_values(by = 'paymentMethodAgeDays')
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 19612              33         1   5.034622    creditcard
# 23719            2000         1   5.040929    creditcard
# 9862              154         1   4.895263    creditcard
# 9863             2000         1   4.057414    creditcard
# 23718            1587         1   2.948940        paypal
# ...               ...       ...        ...           ...
# 10956            2000         1   4.886641    creditcard
# 16357            2000         1   4.886641    creditcard
# 8540             2000         1   4.965339    creditcard
# 4370             2000         1   4.461622    creditcard
# 21241            2000         1   4.742303    creditcard
#
#        paymentMethodAgeDays  label
# 19612              0.000000      0
# 23719              0.000000      0
# 9862               0.000000      0
# 9863               0.000000      0
# 23718              0.000000      0
# ...                     ...    ...
# ...

# %%
countnonfraud = []
countfraud = []
total = []
per = dict()
count = 0
for i in methods:
    print(i)
    temp = nonfraud[nonfraud['paymentMethod'] == i]
    temp2 = fraud[fraud['paymentMethod'] == i]
    temp1 = data[data['paymentMethod'] == i]
    countnonfraud.append(len(temp))
    countfraud.append(len(temp2))
    total.append(len(temp1))
    per[i]=((len(temp)/len(temp1))*100)
print(countnonfraud)
print(countfraud)
print(total)
per
# Out:
# paypal
# storecredit
# creditcard
# [9174, 1893, 27594]
# [129, 21, 410]
# [9303, 1914, 28004]
# {'paypal': 98.61335053208641,
#  'storecredit': 98.90282131661442,
#  'creditcard': 98.53592343950865}

# %%
plt.bar(methods,countnonfraud)
# Out:
# <BarContainer object of 3 artists>

# %%
countfraud=[]
for i in methods:
    temp = fraud[fraud['paymentMethod'] == i]
    countfraud.append(len(temp))

# %%
plt.bar(methods,countfraud)
# Out:
# <BarContainer object of 3 artists>

# %%
totalcount = sum(total)
percentageTotal = sum

# %%
plt.pie(countnonfraud,labels=methods,autopct="%1.1f%%",startangle=0)
plt.show()

# %%
plt.pie(countfraud,labels=methods,autopct="%1.1f%%",startangle=0)
plt.show()

# %%
percentages = []
for i in methods:
    percentages.append(per[i])

# %%
plt.pie(percentages,labels=methods,autopct="%1.5f%%",startangle=0)
plt.show()

# %%
import seaborn as sns
sns.kdeplot(data=nonfraud['numItems'], label='Non-Fraud', shade=True)
sns.kdeplot(data=fraud['numItems'], label='Fraud', shade=True)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_13204\1125951077.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=nonfraud['numItems'], label='Non-Fraud', shade=True)
# C:\Users\navee\AppData\Local\Temp\ipykernel_13204\1125951077.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=fraud['numItems'], label='Fraud', shade=True)
# <Axes: xlabel='numItems', ylabel='Density'>

# %%
fraud.plot()
# Out:
# <Axes: >

# %%
sns.displot(nonfraud['numItems'], kde=True, bins=10, label='Non-Fraud')
sns.displot(fraud['numItems'], kde=True, bins=10, label='Fraud')
plt.ylim(0, 1000)
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\navee\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (0.0, 1000.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

ccfraud = fraud[fraud['paymentMethod'] == 'creditcard']
ccnonfraud = nonfraud[nonfraud['paymentMethod'] == 'creditcard']
# Generate sample data
x1 = ccnonfraud['numItems'].unique()  # Create an array of 100 points from 0 to 10
x2 = ccfraud['numItems'].unique()
y1 = ccnonfraud['numItems'].unique()  # Quadratic curve
y2 = ccfraud['numItems'].unique() # Linear curve


# Plot the curves
plt.plot(x1, y1, label='nonfraud')
plt.plot(x2, y2, label='fraud')


# Add title and labels
plt.title('Comparison of NonFraud and Fraud')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
ccfraud = fraud[fraud['paymentMethod'] == 'creditcard']
ccnonfraud = nonfraud[nonfraud['paymentMethod'] == 'creditcard']
x1 = ccnonfraud['numItems']
x2 = ccfraud['numItems']
y1 = ccnonfraud['numItems'] 
y2 = ccfraud['numItems']

plt.plot(x1, y1, label='nonfraud')
plt.plot(x2, y2, label='fraud')


plt.title('Comparison of NonFraud and Fraud')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

plt.show()

# %%
x1 = nonfraud[nonfraud['paymentMethod'] == 'creditcard']['numItems']
x2 = fraud[fraud['paymentMethod'] == 'creditcard']['numItems']
plt.plot(x1, x1, label='nonfraud')
plt.plot(x2, x2, label='fraud')
plt.title('Comparison of NonFraud and Fraud')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ccfraud = fraud[fraud['paymentMethod'] == 'paypal']
ccnonfraud = nonfraud[nonfraud['paymentMethod'] == 'paypal']
x1 = ccnonfraud['numItems']
x2 = ccfraud['numItems']
y1 = ccnonfraud['numItems'] 
y2 = ccfraud['numItems']

plt.plot(x1, y1, label='nonfraud')
# plt.plot(x2, y2, label='fraud')


plt.title('Comparison of NonFraud and Fraud')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')s
plt.legend()

plt.show()

# %%
plt.plot(x2, y2, label='fraud')

# %%
datacount = []
for i in methods:
    datacount.append(len(data[data['paymentMethod'] == i]))

# %%
plt.pie(datacount,labels=methods,autopct="%1.1f%%",startangle=0)
plt.show()
