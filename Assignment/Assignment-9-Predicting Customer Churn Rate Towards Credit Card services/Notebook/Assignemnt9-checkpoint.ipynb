# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import scipy.stats as stats
import statistics

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df.Attrition_Flag.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    8500
# Attrited Customer    1627
# Name: count, dtype: int64

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df = df.drop(columns = ['CLIENTNUM'])

# %%
df.head()
# Out:
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# ...

# %%
male = df[df.Gender == 'M']

# %% [markdown]
# male

# %%
male
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 2      Existing Customer            51      M                3
# 4      Existing Customer            40      M                3
# 5      Existing Customer            44      M                2
# 6      Existing Customer            51      M                4
# ...                  ...           ...    ...              ...
# 10118  Attrited Customer            50      M                1
# 10120  Existing Customer            54      M                1
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10125  Attrited Customer            30      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# ...

# %%
female = df[df.Gender != 'M']

# %%
female
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 1      Existing Customer            49      F                5
# 3      Existing Customer            40      F                4
# 14     Existing Customer            57      F                2
# 19     Existing Customer            45      F                2
# 21     Attrited Customer            62      F                0
# ...                  ...           ...    ...              ...
# 10106  Existing Customer            58      F                0
# 10119  Attrited Customer            55      F                3
# 10121  Existing Customer            56      F                1
# 10124  Attrited Customer            44      F                1
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 1            Graduate         Single  Less than $40K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# ...

# %%
df.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
zero = df[df.Avg_Utilization_Ratio == 0]

# %%
zero
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 2      Existing Customer            51      M                3
# 4      Existing Customer            40      M                3
# 12     Existing Customer            56      M                1
# 21     Attrited Customer            62      F                0
# 24     Existing Customer            54      M                2
# ...                  ...           ...    ...              ...
# 10109  Existing Customer            47      M                5
# 10112  Attrited Customer            33      M                2
# 10114  Existing Customer            29      M                0
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 2            Graduate        Married    $80K - $120K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...

# %%
zero.Attrition_Flag.value_counts()
# Out:
# Attrition_Flag
# Existing Customer    1577
# Attrited Customer     893
# Name: count, dtype: int64

# %%
Attrited = df[df.Attrition_Flag == 'Attrited Customer']

# %%
Existing = df[df.Attrition_Flag != 'Attrited Customer']

# %%
Attrited.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
li = []
for i in Attrited.columns:
    li.append(Attrited[i].value_acounts())

# %%
for i in li:
    print(i)
# Out:
# Attrition_Flag
# Attrited Customer    1627
# Name: count, dtype: int64
# Customer_Age
# 48    85
# 43    85
# 44    84
# 46    82
# 45    79
# 49    79
# 41    76
# 47    76
# 50    71
# 54    69
# 40    64
# 42    62
# 53    59
# 51    58
# 52    58
# 55    51
# 39    48
# 38    47
# 56    43
# 59    40
# 37    37
# 57    33
# 58    24
# 36    24
# 35    21
# 33    20
# 34    19
# 32    17
# 62    17
# 61    17
# 30    15
# 31    13
# 60    13
# 65     9
# 63     8
# 29     7
# 26     6
# 64     5
# 27     3
# 66     1
# 28     1
# 68     1
# Name: count, dtype: int64
# Gender
# F    930
# M    697
# Name: count, dtype: int64
# Dependent_count
# 3    482
# 2    417
# 1    269
# 4    260
# 0    135
# 5     64
# Name: count, dtype: int64
# Education_Level
# Graduate         487
# High School      306
# Unknown          256
# Uneducated       237
# College          154
# Doctorate         95
# Post-Graduate     92
# Name: count, dtype: int64
# Marital_Status
# Married     709
# ...

# %%
Existing
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10116  Existing Customer            46      M                5
# 10117  Existing Customer            57      M                2
# 10120  Existing Customer            54      M                1
# 10121  Existing Customer            56      F                1
# 10122  Existing Customer            50      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
li = []
for i in Attrited.columns:
    li.append(Existing[i].value_counts())

# %%
for i in li:
    print(i)
# Out:
# Attrition_Flag
# Existing Customer    8500
# Name: count, dtype: int64
# Customer_Age
# 44    416
# 49    416
# 46    408
# 45    407
# 47    403
# 43    388
# 48    387
# 50    381
# 42    364
# 51    340
# 53    328
# 52    318
# 41    303
# 40    297
# 39    285
# 38    256
# 54    238
# 55    228
# 37    223
# 56    219
# 36    197
# 57    190
# 35    163
# 58    133
# 34    127
# 59    117
# 60    114
# 33    107
# 65     92
# 32     89
# 31     78
# 61     76
# 62     76
# 26     72
# 63     57
# 30     55
# 29     49
# 64     38
# 27     29
# 28     28
# 67      4
# 70      1
# 73      1
# 68      1
# 66      1
# Name: count, dtype: int64
# Gender
# F    4428
# M    4072
# Name: count, dtype: int64
# Dependent_count
# 3    2250
# 2    2238
# 1    1569
# 4    1314
# 0     769
# 5     360
# Name: count, dtype: int64
# Education_Level
# Graduate         2641
# High School      1707
# Unknown          1263
# Uneducated       1250
# College           859
# Post-Graduate     424
# ...

# %%
Existing
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10116  Existing Customer            46      M                5
# 10117  Existing Customer            57      M                2
# 10120  Existing Customer            54      M                1
# 10121  Existing Customer            56      F                1
# 10122  Existing Customer            50      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
Attrited
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     Attrited Customer            62      F                0
# 39     Attrited Customer            66      F                0
# 51     Attrited Customer            54      F                1
# 54     Attrited Customer            56      M                2
# 61     Attrited Customer            48      M                2
# ...                  ...           ...    ...              ...
# 10119  Attrited Customer            55      F                3
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 21           Graduate        Married  Less than $40K          Blue
# 39          Doctorate        Married         Unknown          Blue
# ...

# %%
plt.bar(df.Attrition_Flag.value_counts().index,df.Attrition_Flag.value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(df.Attrition_Flag.value_counts(),autopct = '%1.1f%%',explode = (0.1, 0),labels = df.Attrition_Flag.unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x1e995436f50>,
# ...
#  [Text(-1.050367793951052, 0.5802822566910004, 'Existing Customer'),
#   Text(0.9628371693563555, -0.5319253568930898, 'Attrited Customer')],
#  [Text(-0.6127145464714471, 0.3384979830697502, '83.9%'),
#   Text(0.5251839105580121, -0.2901411037598671, '16.1%')])

# %%
plt.bar(df.Gender.value_counts().index,df.Gender.value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.Gender.value_counts()
# Out:
# Gender
# F    5358
# M    4769
# Name: count, dtype: int64

# %%
plt.pie(df.Gender.value_counts(),autopct = '%1.1f%%',labels = df.Gender.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e9968df850>,
# ...
#  [Text(-0.8984771579277663, -0.6346170472671245, 'F'),
#   Text(0.8984771579277667, 0.6346170472671241, 'M')],
#  [Text(-0.49007844977878157, -0.3461547530547952, '52.9%'),
#   Text(0.4900784497787818, 0.34615475305479493, '47.1%')])

# %%
plt.bar(df.Dependent_count.value_counts().index,df.Dependent_count.value_counts().values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.pie(df.Dependent_count.value_counts(),autopct = '%1.1f%%',labels = df.Dependent_count.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e996916ed0>,
# ...
#  [Text(-1.078143561316571, 0.218189049201882, '3'),
#   Text(-0.10907460196120185, -1.0945787916851877, '2'),
#   Text(1.0582778588943813, -0.3000799449712096, '1'),
#   Text(0.7803269079788664, 0.7752998882265765, '4'),
#   Text(0.021894948475137913, 1.0997820744271436, '0'),
#   Text(-0.4203079510603836, 1.0165339277542202, '5')],
#  [Text(-0.5880783061726751, 0.119012208655572, '27.0%'),
#   Text(-0.05949523743338282, -0.5970429772828296, '26.2%'),
#   Text(0.5772424684878443, -0.16367996998429613, '18.1%'),
#   Text(0.4256328588975634, 0.4228908481235871, '15.5%'),
#   Text(0.011942699168257041, 0.5998811315057146, '8.9%'),
#   Text(-0.22925888239657286, 0.5544730515023019, '4.2%')])

# %%
plt.pie(Existing.Dependent_count.value_counts(),autopct = '%1.1f%%',labels = Existing.Dependent_count.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e9a4031310>,
# ...
#  [Text(-1.0745331599039583, 0.23532634418359274, '3'),
#   Text(-0.14001736438193024, -1.0910523074864642, '2'),
#   Text(1.053637248050889, -0.3159882110455222, '1'),
#   Text(0.7864884905092135, 0.7690486683536607, '4'),
#   Text(0.029404039688609024, 1.0996069308848462, '0'),
#   Text(-0.41875994656786486, 1.0171726044042275, '5')],
#  [Text(-0.5861089963112499, 0.1283598241001415, '26.5%'),
#   Text(-0.07637310784468922, -0.5951194404471621, '26.3%'),
#   Text(0.5747112262095758, -0.17235720602483026, '18.5%'),
#   Text(0.4289937220959346, 0.4194810918292694, '15.5%'),
#   Text(0.016038567102877647, 0.5997855986644615, '9.0%'),
#   Text(-0.22841451630974444, 0.554821420584124, '4.2%')])

# %%
plt.pie(Attrited.Dependent_count.value_counts(),autopct = '%1.1f%%',labels = Attrited.Dependent_count.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e9a408a390>,
# ...
#  [Text(-1.092543913929719, 0.12785850044142805, '3'),
#   Text(0.05343298616895536, -1.0987014680927065, '2'),
#   Text(1.0785953476269365, -0.21594461344874516, '1'),
#   Text(0.747336987036081, 0.807147711269649, '4'),
#   Text(-0.017345233430360214, 1.0998632382606697, '0'),
#   Text(-0.4283808307874989, 1.0131583606790266, '5')],
#  [Text(-0.5959330439616649, 0.06974100024077892, '29.6%'),
#   Text(0.029145265183066555, -0.5992917098687489, '25.6%'),
#   Text(0.5883247350692381, -0.1177879709720428, '16.5%'),
#   Text(0.4076383565651351, 0.44026238796526307, '16.0%'),
#   Text(-0.009461036416560117, 0.5999254026876379, '8.3%'),
#   Text(-0.23366227133863574, 0.5526318330976508, '3.9%')])

# %%
plt.xticks(rotation = 45)
plt.bar(df.Marital_Status.value_counts().index,df.Marital_Status.value_counts().values,color=plt.cm.tab10.colors)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = df , x = 'Income_Category',palette='viridis')
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
sns.countplot(data = df,x = 'Card_Category')
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %%
plt.figure(figsize=(13, 7))
plt.pie(df.Card_Category.value_counts(),autopct = '%1.1f%%',labels = df.Card_Category.value_counts().index,startangle = 120,explode = (0.1,0.1,0.1,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e999c981d0>,
# ...
#  [Text(0.36519845149456914, -1.1430792146767297, 'Blue'),
#   Text(-0.31666146230797343, 1.1574651261653528, 'Silver'),
#   Text(-0.5490244330230393, 1.0670389739572452, 'Gold'),
#   Text(-0.5440790089397729, 0.956021983027124, 'Platinum')],
#  [Text(0.21303243003849867, -0.6667962085614255, '93.2%'),
#   Text(-0.18471918634631782, 0.6751879902631225, '5.5%'),
#   Text(-0.3202642525967728, 0.6224394014750596, '1.1%'),
#   Text(-0.29677036851260336, 0.5214665361966131, '0.2%')])

# %%
Attrited
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 21     Attrited Customer            62      F                0
# 39     Attrited Customer            66      F                0
# 51     Attrited Customer            54      F                1
# 54     Attrited Customer            56      M                2
# 61     Attrited Customer            48      M                2
# ...                  ...           ...    ...              ...
# 10119  Attrited Customer            55      F                3
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 21           Graduate        Married  Less than $40K          Blue
# 39          Doctorate        Married         Unknown          Blue
# ...

# %%
plt.pie(Attrited.Gender.value_counts(),autopct = '%1.1f%%',labels = Attrited.Gender.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e999f49610>,
# ...
#  [Text(-0.8059441380993653, -0.7486347883068697, 'F'),
#   Text(0.8059441380993649, 0.7486347883068699, 'M')],
#  [Text(-0.4396058935087446, -0.4083462481673834, '57.2%'),
#   Text(0.4396058935087445, 0.4083462481673835, '42.8%')])

# %%
plt.pie(Existing.Gender.value_counts(),autopct = '%1.1f%%',labels = Existing.Gender.value_counts().index,startangle = 120)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e99a21c510>,
# ...
#  [Text(-0.9144094305044131, -0.6114371540923851, 'F'),
#   Text(0.9144093732575311, 0.6114372397055722, 'M')],
#  [Text(-0.4987687802751344, -0.33351117495948274, '52.1%'),
#   Text(0.49876874904956237, 0.3335112216575848, '47.9%')])

# %%
plt.xticks(rotation = 45)
sns.countplot(data = df,x = 'Education_Level')
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Attrited,x = 'Education_Level')
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Existing,x = 'Education_Level')
# Out:
# <Axes: xlabel='Education_Level', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Existing,x = 'Marital_Status')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Attrited,x = 'Marital_Status')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Existing,x = 'Income_Category')
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
zero = df[df.Avg_Utilization_Ratio == 0]

# %%
plt.xticks(rotation = 45)
sns.countplot(data = zero,x = 'Income_Category')
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
nozero = df[df.Avg_Utilization_Ratio != 0]

# %%
plt.xticks(rotation = 45)
sns.countplot(data = nozero,x = 'Income_Category')
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
plt.xticks(rotation = 45)
sns.countplot(data = Attrited,x = 'Income_Category')
# Out:
# <Axes: xlabel='Income_Category', ylabel='count'>

# %%
Existing
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10116  Existing Customer            46      M                5
# 10117  Existing Customer            57      M                2
# 10120  Existing Customer            54      M                1
# 10121  Existing Customer            56      F                1
# 10122  Existing Customer            50      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %%
plt.hist(df['Total_Trans_Ct'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Ct')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Total_Trans_Ct'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Ct')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Total_Trans_Ct'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Ct')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df['Months_Inactive_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_Inactive_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Months_Inactive_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_Inactive_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Months_Inactive_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_Inactive_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Months_on_book'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_on_book')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Months_on_book'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_on_book')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df['Months_on_book'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Months_on_book')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.countplot(data = Attrited,x = 'Card_Category')
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %%
sns.countplot(data = Existing,x = 'Card_Category')
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %%
sns.countplot(data = df,x = 'Card_Category')
# Out:
# <Axes: xlabel='Card_Category', ylabel='count'>

# %%
plt.hist(df['Total_Trans_Amt'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Total_Trans_Amt'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Total_Trans_Amt'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Total_Trans_Amt'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Total_Trans_Amt'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Total_Trans_Amt')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Dependent_count'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Dependent_count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Dependent_count'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Dependent_count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df['Dependent_count'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Dependent_count')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df['Customer_Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Customer_Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Customer_Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Contacts_Count_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Contacts_Count_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Contacts_Count_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Contacts_Count_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(df['Contacts_Count_12_mon'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Contacts_Count_12_mon')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df['Attrition_Flag'] = df['Attrition_Flag'].replace({'Attrited Customer': 0, 'Existing Customer': 1})

# %%
df.head()
# Out:
#    Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0               1            45      M                3     High School
# 1               1            49      F                5        Graduate
# 2               1            51      M                3        Graduate
# 3               1            40      F                4     High School
# 4               1            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                         5  ...       12691.0                  777
# ...

# %%
df.Attrition_Flag.value_counts()
# Out:
# Attrition_Flag
# 1    8500
# 0    1627
# Name: count, dtype: int64

# %%
inde = df[['Customer_Age','Dependent_count','Months_Inactive_12_mon','Contacts_Count_12_mon','Total_Trans_Amt','Total_Trans_Ct','Avg_Utilization_Ratio']]

# %%
target = df[['Attrition_Flag']]

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.3251989586715204

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
x_train,x_test,y_train,y_test = train_test_split(inde,target,test_size=0.2,random_state = 42)

model = LogisticRegression()

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8390918065153011
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.26      0.35       327
#            1       0.87      0.95      0.91      1699
#
#     accuracy                           0.84      2026
#    macro avg       0.69      0.61      0.63      2026
# weighted avg       0.81      0.84      0.82      2026
# C:\Users\navee\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\navee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
x_train,x_test,y_train,y_test = train_test_split(inde,target,test_size=0.3,random_state= 42)

model = LogisticRegression()

model.fit(x_train,y_train)

y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8344850279697269
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.30      0.37       496
#            1       0.87      0.94      0.90      2543
#
#     accuracy                           0.83      3039
#    macro avg       0.68      0.62      0.64      3039
# weighted avg       0.81      0.83      0.82      3039
# C:\Users\navee\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\navee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
plt.hist(df['Customer_Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Existing['Customer_Age'], bins=15, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(Attrited['Customer_Age'], bins=15, color='skyblue', edgecolor='black')
plt.xlabel('Customer_Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
