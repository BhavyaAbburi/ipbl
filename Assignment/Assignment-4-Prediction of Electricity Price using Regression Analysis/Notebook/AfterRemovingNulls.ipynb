# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv('newcsv.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0   HolidayFlag     DayOfWeek    WeekOfYear           Day  \
# count  38014.000000  38014.000000  38014.000000  38014.000000  38014.000000
# mean   19006.500000      0.040406      2.997317     28.124586     15.739412
# std    10973.840903      0.196912      1.999959     15.587575      8.804247
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     9503.250000      0.000000      1.000000     15.000000      8.000000
# 50%    19006.500000      0.000000      3.000000     29.000000     16.000000
# 75%    28509.750000      0.000000      5.000000     43.000000     23.000000
# max    38013.000000      1.000000      6.000000     52.000000     31.000000
#
#               Month          Year   PeriodOfDay  ForecastWindProduction  \
# count  38014.000000  38014.000000  38014.000000            38014.000000
# mean       6.904246   2012.383859     23.501105              544.261451
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38014 entries, 0 to 38013
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              38014 non-null  int64
#  1   Holiday                 1536 non-null   object
#  2   HolidayFlag             38014 non-null  int64
#  3   DayOfWeek               38014 non-null  int64
#  4   WeekOfYear              38014 non-null  int64
#  5   Day                     38014 non-null  int64
#  6   Month                   38014 non-null  int64
#  7   Year                    38014 non-null  int64
#  8   PeriodOfDay             38014 non-null  int64
#  9   ForecastWindProduction  38014 non-null  float64
#  10  SystemLoadEA            38014 non-null  float64
#  11  SMPEA                   38014 non-null  float64
#  12  ORKTemperature          38014 non-null  float64
#  13  ORKWindspeed            38014 non-null  float64
# ...

# %%
sns.catplot(y='SMPEP2',kind = 'bar',data = df)
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
headers = df.columns

# %%
Actual = df.drop(columns = ['ForecastWindProduction', 'SystemLoadEA', 'SMPEA'])

# %%
Actual
# Out:
#        Unnamed: 0         Holiday  HolidayFlag  DayOfWeek  WeekOfYear  Day  \
# 0               0             NaN            0          1          44    1
# 1               1             NaN            0          1          44    1
# 2               2             NaN            0          1          44    1
# 3               3             NaN            0          1          44    1
# 4               4             NaN            0          1          44    1
# ...           ...             ...          ...        ...         ...  ...
# 38009       38009  New Year's Eve            1          1           1   31
# 38010       38010  New Year's Eve            1          1           1   31
# 38011       38011  New Year's Eve            1          1           1   31
# 38012       38012  New Year's Eve            1          1           1   31
# 38013       38013  New Year's Eve            1          1           1   31
#
# ...

# %%
Predicted = df.drop(columns = ['ActualWindProduction', 'SystemLoadEP2', 'SMPEP2'])

# %%
Predicted
# Out:
#        Unnamed: 0         Holiday  HolidayFlag  DayOfWeek  WeekOfYear  Day  \
# 0               0             NaN            0          1          44    1
# 1               1             NaN            0          1          44    1
# 2               2             NaN            0          1          44    1
# 3               3             NaN            0          1          44    1
# 4               4             NaN            0          1          44    1
# ...           ...             ...          ...        ...         ...  ...
# 38009       38009  New Year's Eve            1          1           1   31
# 38010       38010  New Year's Eve            1          1           1   31
# 38011       38011  New Year's Eve            1          1           1   31
# 38012       38012  New Year's Eve            1          1           1   31
# 38013       38013  New Year's Eve            1          1           1   31
#
# ...

# %%
Holidays =  df[df['Holiday'].notnull()]

# %%
Holidays.describe()
# Out:
#          Unnamed: 0  HolidayFlag   DayOfWeek   WeekOfYear          Day  \
# count   1536.000000       1536.0  1536.00000  1536.000000  1536.000000
# mean   18665.375000          1.0     1.78125    27.875000    17.718750
# std    11595.997213          0.0     2.23308    18.944802    11.024122
# min     2544.000000          1.0     0.00000     1.000000     1.000000
# 25%     7629.750000          1.0     0.00000    13.000000     6.000000
# 50%    20205.500000          1.0     0.50000    21.000000    24.000000
# 75%    25269.250000          1.0     4.00000    51.250000    26.500000
# max    38013.000000          1.0     6.00000    52.000000    31.000000
#
#              Month         Year  PeriodOfDay  ForecastWindProduction  \
# count  1536.000000  1536.000000  1536.000000             1536.000000
# mean      7.468750  2012.312500    23.500000              717.849216
# std       4.032321     0.682017    13.857911              442.657219
# ...

# %%
Holidays['HolidayFlag'].value_counts()
# Out:
# HolidayFlag
# 1    1536
# Name: count, dtype: int64

# %%
onlyNumeric = df.select_dtypes(exclude = object)

# %%
onlyNumeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38014 entries, 0 to 38013
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              38014 non-null  int64
#  1   HolidayFlag             38014 non-null  int64
#  2   DayOfWeek               38014 non-null  int64
#  3   WeekOfYear              38014 non-null  int64
#  4   Day                     38014 non-null  int64
#  5   Month                   38014 non-null  int64
#  6   Year                    38014 non-null  int64
#  7   PeriodOfDay             38014 non-null  int64
#  8   ForecastWindProduction  38014 non-null  float64
#  9   SystemLoadEA            38014 non-null  float64
#  10  SMPEA                   38014 non-null  float64
#  11  ORKTemperature          38014 non-null  float64
#  12  ORKWindspeed            38014 non-null  float64
#  13  CO2Intensity            38014 non-null  float64
# ...

# %%
plt.figure(figsize = (40,20))
sns.heatmap(onlyNumeric[['ForecastWindProduction',
       'SystemLoadEA', 'SMPEA','ActualWindProduction', 'SystemLoadEP2', 'SMPEP2']].corr(),annot=True)
# Out:
# <Axes: >

# %%
df.groupby('Month')['SMPEP2'].mean().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df.describe()
# Out:
#          Unnamed: 0   HolidayFlag     DayOfWeek    WeekOfYear           Day  \
# count  38014.000000  38014.000000  38014.000000  38014.000000  38014.000000
# mean   19006.500000      0.040406      2.997317     28.124586     15.739412
# std    10973.840903      0.196912      1.999959     15.587575      8.804247
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     9503.250000      0.000000      1.000000     15.000000      8.000000
# 50%    19006.500000      0.000000      3.000000     29.000000     16.000000
# 75%    28509.750000      0.000000      5.000000     43.000000     23.000000
# max    38013.000000      1.000000      6.000000     52.000000     31.000000
#
#               Month          Year   PeriodOfDay  ForecastWindProduction  \
# count  38014.000000  38014.000000  38014.000000            38014.000000
# mean       6.904246   2012.383859     23.501105              544.261451
# ...

# %%
sns.pairplot(df.head())
# Out:
# C:\Users\navee\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
